# %%
import matplotlib.pyplot as pypl
import numpy as np
import sympy as sp

# %%
# Definiton of funcitons:

fun_1 = x
fun_2 = 2*x**2

# %%
# Plotting graphical solutions:

x = np.linspace(-5,5,100)
pypl.plot(x, fun_1, label='Linear 1')
pypl.plot(x, fun_2, label='Square 2')
pypl.legend()
pypl.show()

# %%
# x sp.symbols('x')
print(sp.solve(fun_1))
print(sp.solve(fun_2))
# Out:
# []
# []
